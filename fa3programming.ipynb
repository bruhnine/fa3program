# %% [markdown]
# <a href="https://colab.research.google.com/github/bruhnine/fa3program/blob/main/fa3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Enter your name:")
age = input(f"Hello, {name}! How old are you?" )
course = input("What course are you in?")

print("Name:" , name)
print("Age:" , age)
print("Course:" , course)
# Out:
# Enter your name:Genine
# Hello, Genine! How old are you?13
# What course are you in?Medicine
# Name: Genine
# Age: 13
# Course: Medicine

# %%
score = int(input("Enter your exam score: "))

if score >= 25 and score <= 50:
  print("Passed")
elif score < 25:
  print("Failed")
else:
  print("Invalid score")
# Out:
# Enter your exam score: 35
# Passed

# %%
name = input("Enter your name: ")
score = int(input("Enter your exam score: "))

if score >= 90 and score <= 100:
  print("A'")
elif score >= 80 and score <= 89:
  print("B")
elif score >= 70 and score <= 79:
  print("C")
elif score >= 0 and score <= 69:
  print("F")
else:
  print("Invalid score")
# Out:
# Enter your name: Genine
# Enter your exam score: 123
# Invalid score
